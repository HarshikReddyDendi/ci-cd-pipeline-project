# %%
print("CI/CD Pipeline Automation Project")

a = 10
b = 20

print("Sum =", a + b)
# Out:
# CI/CD Pipeline Automation Project
# Sum = 30
# [NbConvertApp] Converting notebook ci_pipeline.ipynb to script
# [NbConvertApp] Writing 0 bytes to ci_pipeline.txt

# %%
# !jupyter nbconvert --to script ci_pipeline.ipynb
# Out:
# [NbConvertApp] Converting notebook ci_pipeline.ipynb to script
# [NbConvertApp] Writing 218 bytes to ci_pipeline.py
